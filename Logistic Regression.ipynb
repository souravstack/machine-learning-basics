# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("marital status.csv")

# %%
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     1.0
# 8    19     0.0
# 9    22     0.0
# 10   26     0.0
# 11   20     0.0
# 12   24     NaN
# 13   34     1.0
# 14   29     1.0
# 15   16     0.0
# 16   18     0.0
# 17   25     1.0

# %%
df.isnull().sum()
# Out:
# age       0
# status    1
# dtype: int64

# %%
handel=df['status'].median()

# %%
handel
# Out:
# 0.0

# %%
df.status=df.status.fillna(handel)

# %%
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     1.0
# 8    19     0.0
# 9    22     0.0
# 10   26     0.0
# 11   20     0.0
# 12   24     0.0
# 13   34     1.0
# 14   29     1.0
# 15   16     0.0
# 16   18     0.0
# 17   25     1.0

# %%
df['status'].value_counts()
# Out:
# status
# 0.0    11
# 1.0     7
# Name: count, dtype: int64

# %%
x=df[['age']]
x
# Out:
#     age
# 0    21
# 1    33
# 2    24
# 3    28
# 4    17
# 5    33
# 6    23
# 7    30
# 8    19
# 9    22
# 10   26
# 11   20
# 12   24
# 13   34
# 14   29
# 15   16
# 16   18
# 17   25

# %%
y=df['status']
y
# Out:
# 0     0.0
# 1     1.0
# 2     0.0
# 3     1.0
# 4     0.0
# 5     1.0
# 6     0.0
# 7     1.0
# 8     0.0
# 9     0.0
# 10    0.0
# 11    0.0
# 12    0.0
# 13    1.0
# 14    1.0
# 15    0.0
# 16    0.0
# 17    1.0
# Name: status, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
xtest
# Out:
#     age
# 0    21
# 1    33
# 8    19
# 5    33
# 3    28
# 13   34

# %%
ytest
# Out:
# 0     0.0
# 1     1.0
# 8     0.0
# 5     1.0
# 3     1.0
# 13    1.0
# Name: status, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model.predict(xtest)
# Out:
# array([0., 1., 0., 1., 1., 1.])

# %%
model.score(xtest,ytest)
# Out:
# 1.0

# %%
model.predict_proba(xtest)
# Out:
# array([[0.98391803, 0.01608197],
#        [0.00473639, 0.99526361],
#        [0.99663438, 0.00336562],
#        [0.00473639, 0.99526361],
#        [0.19695913, 0.80304087],
#        [0.00215846, 0.99784154]])
